// %% [markdown]
// ## Analysis of dilepton final state from ATLAS OpenData 13TeV dataset

// %%
#include <iostream>
#include <fstream>
#include <algorithm>

// %% [markdown]
// ### Structure of OpenData (13TeV):
// - Data is stored in nTuples, i.e. 'trees'
// - One event = one entry in the tree
// - One variable = one 'branch' in the tree (branch = integers/floats/vectors/booleans etc.)
// - All events have the same branches
//
//
// TChain is used in order to link together data from several nTuples, i.e. it is a 'chain of trees'.
// Would typically like one chain for real data and one for MC (background).

// %%
/*

1. Reading the dataset and obtaining header variables

*/

TChain *background = new TChain("mini");
TChain *data = new TChain("mini");

// %%
TString sample; 
TString path; 
TString type;
vector<Int_t> dataset_IDs;
vector<TString> types;
Int_t DSID;

// %%
ifstream infile1("../Input/13TeV/dataset_MCInput.txt");

string name ;

// %%
infile1.clear();
infile1.seekg(0, ios::beg);  // Start at the beginning of the file

background->Reset(); // Reset the TChain (if necessary)
DSID = 0;

//while (!infile.fail() && !infile.eof() ){
while (infile1 >> sample >> DSID >> type){
        path = "../Input/13TeV/MC/"+sample;
        background->Add(path);
        dataset_IDs.push_back(DSID);
        types.push_back(type);
        cout << sample << endl;
}
// Out:
// mc_410000.ttbar_lep.2lep.root
// mc_364100.Zmumu_PTV0_70_CVetoBVeto.2lep.root
// mc_364101.Zmumu_PTV0_70_CFilterBVeto.2lep.root
// mc_364102.Zmumu_PTV0_70_BFilter.2lep.root
// mc_364103.Zmumu_PTV70_140_CVetoBVeto.2lep.root
// mc_364104.Zmumu_PTV70_140_CFilterBVeto.2lep.root
// mc_364105.Zmumu_PTV70_140_BFilter.2lep.root
// mc_364106.Zmumu_PTV140_280_CVetoBVeto.2lep.root
// mc_364107.Zmumu_PTV140_280_CFilterBVeto.2lep.root
// mc_364108.Zmumu_PTV140_280_BFilter.2lep.root
// mc_364109.Zmumu_PTV280_500_CVetoBVeto.2lep.root
// mc_364110.Zmumu_PTV280_500_CFilterBVeto.2lep.root
// mc_364111.Zmumu_PTV280_500_BFilter.2lep.root
// mc_364112.Zmumu_PTV500_1000.2lep.root
// mc_364113.Zmumu_PTV1000_E_CMS.2lep.root
// mc_364114.Zee_PTV0_70_CVetoBVeto.2lep.root
// mc_364115.Zee_PTV0_70_CFilterBVeto.2lep.root
// mc_364116.Zee_PTV0_70_BFilter.2lep.root
// mc_364117.Zee_PTV70_140_CVetoBVeto.2lep.root
// mc_364118.Zee_PTV70_140_CFilterBVeto.2lep.root
// mc_364119.Zee_PTV70_140_BFilter.2lep.root
// mc_364120.Zee_PTV140_280_CVetoBVeto.2lep.root
// mc_364121.Zee_PTV140_280_CFilterBVeto.2lep.root
// mc_364122.Zee_PTV140_280_BFilter.2lep.root
// mc_364123.Zee_PTV280_500_CVetoBVeto.2lep.root
// mc_364124.Zee_PTV280_500_CFilterBVeto.2lep.root
// mc_364125.Zee_PTV280_500_BFilter.2lep.root
// mc_364126.Zee_PTV500_1000.2lep.root
// mc_364127.Zee_PTV1000_E_CMS.2lep.root
// mc_364128.Ztautau_PTV0_70_CVetoBVeto.2lep.root
// mc_364129.Ztautau_PTV0_70_CFilterBVeto.2lep.root
// mc_364130.Ztautau_PTV0_70_BFilter.2lep.root
// mc_364131.Ztautau_PTV70_140_CVetoBVeto.2lep.root
// mc_364132.Ztautau_PTV70_140_CFilterBVeto.2lep.root
// mc_364133.Ztautau_PTV70_140_BFilter.2lep.root
// mc_364134.Ztautau_PTV140_280_CVetoBVeto.2lep.root
// mc_364135.Ztautau_PTV140_280_CFilterBVeto.2lep.root
// mc_364136.Ztautau_PTV140_280_BFilter.2lep.root
// mc_364137.Ztautau_PTV280_500_CVetoBVeto.2lep.root
// mc_364138.Ztautau_PTV280_500_CFilterBVeto.2lep.root
// mc_364139.Ztautau_PTV280_500_BFilter.2lep.root
// mc_364140.Ztautau_PTV500_1000.2lep.root
// mc_364141.Ztautau_PTV1000_E_CMS.2lep.root
// mc_363356.ZqqZll.2lep.root
// mc_363358.WqqZll.2lep.root
// mc_363359.WpqqWmlv.2lep.root
// mc_363360.WplvWmqq.2lep.root
// mc_363490.llll.2lep.root
// mc_363491.lllv.2lep.root
// mc_363492.llvv.2lep.root
// mc_363493.lvvv.2lep.root
// mc_305550.Gee_01_750.2lep.root
// mc_305553.Gee_01_1000.2lep.root
// mc_305556.Gee_01_2000.2lep.root
// mc_305559.Gee_01_3000.2lep.root
// mc_305562.Gee_01_4000.2lep.root
// mc_305568.Gmumu_01_750.2lep.root
// mc_305571.Gmumu_01_1000.2lep.root
// mc_305574.Gmumu_01_2000.2lep.root
// mc_305577.Gmumu_01_3000.2lep.root

// %%
ifstream infile2("../Input/13TeV/dataset_dataInput.txt");

// %%
data->Reset();
infile2.clear();
infile2.seekg(0, ios::beg);

while (infile2 >> sample){
        path = "../Input/13TeV/Data/"+sample;
        data->Add(path);
}

// %%
// Add individual DSIDs to corresponding types
vector<Int_t> Zjets, ttbar, graviton, Zprime, Dibosons, tt;

// %%
Zjets.clear();
ttbar.clear();
Dibosons.clear();
graviton.clear();
Zprime.clear();
tt.clear();

for(int j=0; j<types.size(); j++){
    if (types[j] == "Z+jets"){Zjets.push_back(dataset_IDs[j]); }
    else if (types[j] == "ttbar"){ttbar.push_back(dataset_IDs[j]); }
    else if (types[j] == "Graviton"){graviton.push_back(dataset_IDs[j]); }
    else if (types[j] == "Zprime"){Zprime.push_back(dataset_IDs[j]); }
    else if (types[j] == "Dibosons"){Dibosons.push_back(dataset_IDs[j]); }
    else if (types[j] == "tt"){tt.push_back(dataset_IDs[j]); }
}

// %%
// Assign branch variables to variables defined below

Int_t lep_n;
Int_t channelNumber;
Float_t XSection, met_et, mcWeight, SumWeights;
Bool_t trigE, trigM;
vector<Int_t> *lep_type, *lep_charge;
vector<Float_t> *lep_pt, *lep_E, *lep_phi, *lep_eta, *lep_etcone20, *lep_ptcone30, *lep_z0, *lep_trackd0pvunbiased, *lep_tracksigd0pvunbiased;
vector<Bool_t> *trigMatched, *lep_isTightID;

// %%
Float_t scaleFactor_PILEUP, scaleFactor_ELE, scaleFactor_MUON, scaleFactor_BTAG, scaleFactor_lepTRIGGER;

// %%
// Obtain header variables

// For MC:  
background->SetBranchAddress("lep_n",      &lep_n);
background->SetBranchAddress("lep_charge", &lep_charge);
background->SetBranchAddress("lep_type",   &lep_type);
background->SetBranchAddress("lep_pt",     &lep_pt);
background->SetBranchAddress("lep_eta",    &lep_eta);
background->SetBranchAddress("lep_phi",    &lep_phi);
background->SetBranchAddress("lep_E",      &lep_E);
background->SetBranchAddress("met_et",     &met_et); 
background->SetBranchAddress("channelNumber", &channelNumber);
background->SetBranchAddress("mcWeight", &mcWeight);
background->SetBranchAddress("scaleFactor_PILEUP", &scaleFactor_PILEUP );
background->SetBranchAddress("scaleFactor_ELE", &scaleFactor_ELE ); 
background->SetBranchAddress("scaleFactor_MUON", &scaleFactor_MUON ); 
background->SetBranchAddress("scaleFactor_BTAG", &scaleFactor_BTAG );
background->SetBranchAddress("scaleFactor_LepTRIGGER", &scaleFactor_lepTRIGGER );
background->SetBranchAddress("lep_isTightID", &lep_isTightID); 
background->SetBranchAddress("lep_ptcone30", &lep_ptcone30);
background->SetBranchAddress("lep_etcone20", &lep_etcone20);
background->SetBranchAddress("trigE", &trigE);
background->SetBranchAddress("trigM", &trigM);
background->SetBranchAddress("SumWeights", &SumWeights);
background->SetBranchAddress("XSection", &XSection); 
background->SetBranchAddress("lep_z0", &lep_z0);
background->SetBranchAddress("lep_trackd0pvunbiased", &lep_trackd0pvunbiased);
background->SetBranchAddress("lep_tracksigd0pvunbiased", &lep_tracksigd0pvunbiased);

// For data:
data->SetBranchAddress("lep_n",      &lep_n);
data->SetBranchAddress("lep_charge", &lep_charge);
data->SetBranchAddress("lep_type",   &lep_type);
data->SetBranchAddress("lep_pt",     &lep_pt);
data->SetBranchAddress("lep_eta",    &lep_eta);
data->SetBranchAddress("lep_phi",    &lep_phi);
data->SetBranchAddress("lep_E",      &lep_E);
data->SetBranchAddress("met_et",     &met_et); 
data->SetBranchAddress("channelNumber", &channelNumber);
data->SetBranchAddress("trigE", &trigE); 
data->SetBranchAddress("trigM", &trigM);
data->SetBranchAddress("lep_isTightID", &lep_isTightID);
data->SetBranchAddress("lep_ptcone30", &lep_ptcone30); 
data->SetBranchAddress("lep_etcone20", &lep_etcone20);
data->SetBranchAddress("lep_z0", &lep_z0);
data->SetBranchAddress("lep_trackd0pvunbiased", &lep_trackd0pvunbiased);
data->SetBranchAddress("lep_tracksigd0pvunbiased", &lep_tracksigd0pvunbiased);

// %%
/*

2. Analysis of data and obtaining the desired final states by cuts

*/

// 1. Create map of histograms for background events

// Declaring map containing 1D histograms, in which each histogram contains values of type Int_t
map<Int_t, TH1*> hist_mll; 
map<Int_t, TH1*> hist_lep_pt; 
map<Int_t, TH1*> hist_met;

// Assign each DSID in datasetIDs as a unique input element i in histograms
for(const auto & i:dataset_IDs){
    hist_mll[i] = new TH1F(); 
    hist_lep_pt[i] = new TH1F(); 
    hist_met[i] = new TH1F();
}

for(const auto & i:dataset_IDs){
//    cout << i << endl;
    hist_mll[i]->SetNameTitle("hist_mll", "Invariant mass"); 
    hist_lep_pt[i]->SetNameTitle("hist_lep_pt", "Lepton pT"); 
    hist_met[i]->SetNameTitle("hist_met", "Missing ET");
    hist_mll[i]->SetBins(30,0,2500); 
    hist_lep_pt[i]->SetBins(30,0,2000);
    hist_met[i]->SetBins(30,0,3000); 
}

// %%
// 2. Create histogram for recorded data events

hist_mll_d = new TH1F(); 
hist_lep_pt_d = new TH1F(); 
hist_met_d = new TH1F();

// %%
hist_mll_d->SetNameTitle("hist_mll", "Invariant mass");
hist_lep_pt_d->SetNameTitle("hist_lep_pt", "Lepton pT"); 
hist_met_d->SetNameTitle("hist_met", "Missing ET");
hist_mll_d->SetBins(30,0,2500); 
hist_lep_pt_d->SetBins(30,0,2000);
hist_met_d->SetBins(30,0,3000);

// %%
// 3. Create histogram for signal + background events
hist_mll_sb = new TH1F();
hist_lep_pt_sb = new TH1F();
hist_met_sb = new TH1F();

// %%
hist_mll_sb->SetNameTitle("", "Invariant mass"); 
hist_lep_pt_sb->SetNameTitle("hist_lep_pt", "Lepton pT"); 
hist_met_sb->SetNameTitle("hist_met", "Missing ET");
hist_mll_sb->SetBins(30,0,2500); 
hist_lep_pt_sb->SetBins(30,0,2000);
hist_met_sb->SetBins(30,0,3000);

// %%
// Lorentz vectors for decay products
TLorentzVector l1, l2, dileptons, l1temp, l2temp;

// %%
TChain *dataset = new TChain("mini");
TString channel;
vector<Int_t> DSIDs;// datasetIDs
int isData; 
int nentries; //number of entries in each input file
int zjets, Ttbar, dibosons, gravitons, zprime, j, Tt; // counters
Float_t W; // weight
Double_t L;   //Integrated luminosity

L = 10000.; //pb
DSIDs.push_back(0);
j = zjets = Ttbar = gravitons = zprime = dibosons = Tt = 0;

// %% [markdown]
// ### Cuts for the individual lepton pairs:
// The primary vertex chosen is the one with the highest summed $p_T^2$ of tracks with transverse momentum $p_T > 0.5$GeV associated with the vertex.
//
// 1. __Preselection and final cut requirements__:
//     - Require only 2 leptons in the final state
//     - Require same-flavour leptons
//     - Muon pair must have opposite charges
//     - Electron pair has no requirement on opposite charges due to the higher probability of charge misidentification for high $E_T$-electrons (if we had an opposite charge requirement).
//
//
// 2. __Reconstructed electrons must__
//    - have $E_T > 30$GeV
//    - have $|\eta| < 2.47$ (in order to pass through the fine-granularity region of the EM calorimeter)
//    - be outside the range $1.37 < |\eta| < 1.52$ (corresponding to the transition region between the barrel and endcap EM calorimeters)
//    - have $|z_0\sin\Theta| < 0.5$mm (in order to be consistent with the primary vertex along the beamline)
//    - have $|d_0/\sigma(d_0)| < 5$ (in order to be consistent with the primary vertex transverse to the beamline)
//
//
// 3. __Reconstructed muons must__
//     - have $p_T > 30$GeV
//     - have $|\eta| < 2.5$ (in order to pass through the fine-granularity region of the EM calorimeter)
//     - be outside the range $1.01 < |\eta| < 1.1$ (corresponding to the transition region between the barrel and endcap EM calorimeters)
//     - have $|z_0\sin\Theta| < 0.5$mm (in order to be consistent with the primary vertex along the beamline)
//     - have $|d_0/\sigma(d_0)| < 3$ (in order to be consistent with the primary vertex transverse to the beamline)

// %%
// Reset histograms (in case you have filled them before) 
for(const auto & i:dataset_IDs){ 
    hist_mll[i]->Reset(); 
    hist_lep_pt[i]->Reset(); 
    hist_met[i]->Reset();
}

hist_mll_d->Reset();
hist_lep_pt_d->Reset(); 
hist_met_d->Reset(); 



// Loop through all events in background and data separately
for(isData = 0; isData<2; isData++){
    if(isData == 1){
        nentries = data->GetEntries();
        dataset = data;
        cout << "Running over data..." << endl; 
        cout << "Number entries: " << nentries << endl;
    }
    else {
        nentries = background->GetEntries();
        dataset = background;
        cout << "Running over background..." << endl;
        cout << "Number entries: " << nentries << endl;
    }

    //running over all events within data and background
    for (int i = 0; i < nentries; i++){    //i<nentries 
//        if(i%1000000 == 0 && i>0){ cout << "lep_type[0]: "<< lep_type[0] << endl;}
//        if(i%1000000 == 0 && i>0){ cout << "lep_type->at(0): "<< lep_type->at(0) << endl;}
//        cout << "i = " << i << endl;
//        cout << "lep_type[0]: "<< *lep_type[0] << endl;        
//        cout << "lep_charge->at(0): " << lep_charge->at(0) << endl;
//        cout << "lep_type->at(0): "<< lep_type->at(0) << endl;

        if(i%1000000 == 0 && i>0){ cout << "------------------------------------------" << endl;}
        if(i%1000000 == 0 && i>0){ cout << i/1000000 << " million events processed" << endl;}
        if(i%1000000 == 0 && i>0){ cout << "------------------------------------------" << endl;}

         // We "pull out" the i'th entry in the chain. The variables are now 
         // available through the names we have given them.
        dataset->GetEntry(i);
    
        
        // Cut #1: Require (exactly) 2 leptons
        if(lep_n != 2){ continue; }
        // Cut #2: Require same flavour (2 electrons or 2 muons)
        if(lep_type->at(0) != lep_type->at(1)){ continue; }

        // Set Lorentz vectors
        l1.SetPtEtaPhiE(lep_pt->at(0)/1000., lep_eta->at(0), lep_phi->at(0), lep_E->at(0)/1000.);
        l2.SetPtEtaPhiE(lep_pt->at(1)/1000., lep_eta->at(1), lep_phi->at(1), lep_E->at(1)/1000.);

        // Cut #3: Cut on z_0 impact parameter
        if( fabs(lep_z0->at(0)*TMath::Sin(l1.Theta())) > 0.5 ){ continue; }
        if( fabs(lep_z0->at(1)*TMath::Sin(l2.Theta())) > 0.5 ){ continue; }

        // Cut #4: Lepton isolation cuts
        if( lep_ptcone30->at(0)/(lep_pt->at(0)) > 0.15 ){ continue; }
        if( lep_ptcone30->at(1)/(lep_pt->at(1)) > 0.15 ){ continue; }

        if( lep_etcone20->at(0)/(lep_pt->at(0)) > 0.15 ){ continue; }
        if( lep_etcone20->at(1)/(lep_pt->at(1)) > 0.15 ){ continue; }

        if( lep_etcone20->at(0)/(lep_pt->at(0)) < -0.1 || lep_etcone20->at(0)/(lep_pt->at(0)) > 0.2 ){ continue; } // || = or operator
        if( lep_etcone20->at(1)/(lep_pt->at(1)) < -0.1 || lep_etcone20->at(1)/(lep_pt->at(1)) > 0.2 ){ continue; } // || = or operator

        if( lep_pt->at(0)/1000.0 < 30 ){ continue; }        
        if( lep_pt->at(1)/1000.0 < 30 ){ continue; }       
       
        // Identify leptons
        if( fabs(lep_type->at(0)) == 11 ){ channel = "ee"; }
        if( fabs(lep_type->at(0)) == 13 ){ channel = "uu"; }
        
        
        //Cuts on individual muons and electrons:       
        // Electrons
        if( channel == "ee"){
            if( fabs(lep_eta->at(0)) > 2.47 ){ continue; }
            if( fabs(lep_eta->at(0)) > 1.37 && fabs(lep_eta->at(0)) < 1.52){ continue; }
            if( lep_E->at(0)/1000.0 < 30 ){ continue; }
            if( fabs(lep_trackd0pvunbiased->at(0)/(lep_tracksigd0pvunbiased->at(0))) > 5 ){ continue; }

            if( lep_E->at(1)/1000.0 < 30 ){ continue; }
            if( fabs(lep_eta->at(1)) > 2.47 ){ continue; }
            if( fabs(lep_eta->at(1)) > 1.37 && fabs(lep_eta->at(1)) < 1.52){ continue; }
            if( fabs(lep_trackd0pvunbiased->at(1)/(lep_tracksigd0pvunbiased->at(1))) > 5 ){ continue; }
        }

        // Muons
        if( channel == "uu"){
            // Require opposite charge
            if(lep_charge->at(0) == lep_charge->at(1)){ continue; }

            if( lep_pt->at(0)/1000.0 < 30 ){ continue; }  //25 GeV = standard cut for triggers for good accuracy
            if( fabs(lep_eta->at(0)) > 2.5 ){ continue; }
            if( fabs(lep_eta->at(0)) > 1.01 && fabs(lep_eta->at(0)) < 1.1){ continue; }
            if( fabs(lep_trackd0pvunbiased->at(0)/(lep_tracksigd0pvunbiased->at(0))) > 3 ){ continue; }

            if( lep_pt->at(1)/1000.0 < 30 ){ continue; }
            if( fabs(lep_eta->at(1)) > 2.5 ){ continue; }
            if( fabs(lep_eta->at(1)) > 1.01 && fabs(lep_eta->at(1)) < 1.1){ continue; }
            if( fabs(lep_trackd0pvunbiased->at(1)/(lep_tracksigd0pvunbiased->at(1))) > 3 ){ continue; }
        }

        // If an event passes all criterias above then obtain invariant mass, pT and missing transverse E
               
        dileptons = l1 + l2;
        if (dileptons.M() < 80){ continue; }
        
        if(isData == 1)
        {
            hist_mll_d->Fill(dileptons.M());
            hist_lep_pt_d->Fill(l1.Pt());
            hist_lep_pt_d->Fill(l2.Pt()); 
            hist_met_d->Fill(met_et/1000.); 
        }
        
        else
        {
            j++;
            DSIDs.push_back(channelNumber);
            
            // Count number of events included in plotting within each background and signal
            if(std::find(Zjets.begin(), Zjets.end(), channelNumber) != Zjets.end()){zjets++; }
            if(std::find(ttbar.begin(), ttbar.end(), channelNumber) != ttbar.end()){Ttbar++; }
            if(std::find(graviton.begin(), graviton.end(), channelNumber) != graviton.end()){gravitons++; }
            if(std::find(Zprime.begin(), Zprime.end(), channelNumber) != Zprime.end()){zprime++; }
            if(std::find(Dibosons.begin(), Dibosons.end(), channelNumber) != Dibosons.end()){dibosons++; }

            // Scaling
            W = (XSection*L/SumWeights)*mcWeight*scaleFactor_PILEUP*scaleFactor_ELE*scaleFactor_MUON*scaleFactor_BTAG*scaleFactor_lepTRIGGER; // *scaleFactor_JVFSF*scaleFactor_ZVERTEX; 

            // Fill histograms
            // (signal + background)
            hist_mll_sb->Fill(dileptons.M(), W);
            hist_lep_pt_sb->Fill(l1.Pt(), W);
            hist_lep_pt_sb->Fill(l2.Pt(), W);
            hist_met_sb->Fill(met_et/1000., W);
            
            // (background)
            hist_mll[channelNumber]->Fill(dileptons.M(), W);
            hist_lep_pt[channelNumber]->Fill(l1.Pt(), W);
            hist_lep_pt[channelNumber]->Fill(l2.Pt(), W);
            hist_met[channelNumber]->Fill(met_et/1000., W);            
        }
        
        // Preselection (variables are stored in the TTree with unit MeV, so we need to divide by 1000 
        // to get GeV, which is a more practical and commonly used unit):

/*        
        // Cut #1: Require (exactly) 2 leptons
        if(lep_n != 2){ continue; }
        // Cut #2: Require same flavour (2 electrons or 2 muons)
        if(*lep_type[0] != *lep_type[1]){ continue; }

        // Set Lorentz vectors
        l1.SetPtEtaPhiE(*lep_pt[0]/1000., *lep_eta[0], *lep_phi[0], *lep_E[0]/1000.);
        l2.SetPtEtaPhiE(*lep_pt[1]/1000., *lep_eta[1], *lep_phi[1], *lep_E[1]/1000.);

        // Cut #3: Cut on z_0 impact parameter
        if( fabs(*lep_z0[0]*TMath::Sin(l1.Theta())) > 0.5 ){ continue; }
        if( fabs(*lep_z0[1]*TMath::Sin(l2.Theta())) > 0.5 ){ continue; }

        // Cut #4: Lepton isolation cuts
        if( *lep_ptcone30[0]/(*lep_pt[0]) > 0.15 ){ continue; }
        if( *lep_ptcone30[1]/(*lep_pt[1]) > 0.15 ){ continue; }

        if( *lep_etcone20[0]/(*lep_pt[0]) > 0.15 ){ continue; }
        if( *lep_etcone20[1]/(*lep_pt[1]) > 0.15 ){ continue; }

        if( *lep_etcone20[0]/(*lep_pt[0]) < -0.1 || *lep_etcone20[0]/(*lep_pt[0]) > 0.2 ){ continue; } // || = or operator
        if( *lep_etcone20[1]/(*lep_pt[1]) < -0.1 || *lep_etcone20[1]/(*lep_pt[1]) > 0.2 ){ continue; } // || = or operator

        if( *lep_pt[0]/1000.0 < 30 ){ continue; }        
        if( *lep_pt[1]/1000.0 < 30 ){ continue; }       
       
        // Identify leptons
        if( fabs(*lep_type[0]) == 11 ){ channel = "ee"; }
        if( fabs(*lep_type[0]) == 13 ){ channel = "uu"; }
        
        
        //Cuts on individual muons and electrons:       
        // Electrons
        if( channel == "ee"){
            if( fabs(*lep_eta[0]) > 2.47 ){ continue; }
            if( fabs(*lep_eta[0]) > 1.37 && fabs(*lep_eta[0]) < 1.52){ continue; }
            if( *lep_E[0]/1000.0 < 30 ){ continue; }
            if( fabs(*lep_trackd0pvunbiased[0]/(*lep_tracksigd0pvunbiased[0])) > 5 ){ continue; }

            if( *lep_E[1]/1000.0 < 30 ){ continue; }
            if( fabs(*lep_eta[1]) > 2.47 ){ continue; }
            if( fabs(*lep_eta[1]) > 1.37 && fabs(*lep_eta[1]) < 1.52){ continue; }
            if( fabs(*lep_trackd0pvunbiased[1]/(*lep_tracksigd0pvunbiased[1])) > 5 ){ continue; }
        }

        // Muons
        if( channel == "uu"){
            // Require opposite charge
            if(*lep_charge[0] == *lep_charge[1]){ continue; }

            if( *lep_pt[0]/1000.0 < 30 ){ continue; }  //25 GeV = standard cut for triggers for good accuracy
            if( fabs(*lep_eta[0]) > 2.5 ){ continue; }
            if( fabs(*lep_eta[0]) > 1.01 && fabs(*lep_eta[0]) < 1.1){ continue; }
            if( fabs(*lep_trackd0pvunbiased[0]/(*lep_tracksigd0pvunbiased[0])) > 3 ){ continue; }

            if( *lep_pt[1]/1000.0 < 30 ){ continue; }
            if( fabs(*lep_eta[1]) > 2.5 ){ continue; }
            if( fabs(*lep_eta[1]) > 1.01 && fabs(*lep_eta[1]) < 1.1){ continue; }
            if( fabs(*lep_trackd0pvunbiased[1]/(*lep_tracksigd0pvunbiased[1])) > 3 ){ continue; }
        }

        // If an event passes all criterias above then obtain invariant mass, pT and missing transverse E
               
        dileptons = l1 + l2;
        if (dileptons.M() < 80){ continue; }
        
        if(isData == 1)
        {
            hist_mll_d->Fill(dileptons.M());
            hist_lep_pt_d->Fill(l1.Pt());
            hist_lep_pt_d->Fill(l2.Pt()); 
            hist_met_d->Fill(met_et/1000.); 
        }
        
        else
        {
            j++;
            DSIDs.push_back(channelNumber);
            
            // Count number of events included in plotting within each background and signal
            if(std::find(Zjets.begin(), Zjets.end(), channelNumber) != Zjets.end()){zjets++; }
            if(std::find(ttbar.begin(), ttbar.end(), channelNumber) != ttbar.end()){Ttbar++; }
            if(std::find(graviton.begin(), graviton.end(), channelNumber) != graviton.end()){gravitons++; }
            if(std::find(Zprime.begin(), Zprime.end(), channelNumber) != Zprime.end()){zprime++; }
            if(std::find(Dibosons.begin(), Dibosons.end(), channelNumber) != Dibosons.end()){dibosons++; }

            // Scaling
            W = (XSection*L/SumWeights)*mcWeight*scaleFactor_PILEUP*scaleFactor_ELE*scaleFactor_MUON*scaleFactor_BTAG*scaleFactor_lepTRIGGER; // *scaleFactor_JVFSF*scaleFactor_ZVERTEX; 

            // Fill histograms
            // (signal + background)
            hist_mll_sb->Fill(dileptons.M(), W);
            hist_lep_pt_sb->Fill(l1.Pt(), W);
            hist_lep_pt_sb->Fill(l2.Pt(), W);
            hist_met_sb->Fill(met_et/1000., W);
            
            // (background)
            hist_mll[channelNumber]->Fill(dileptons.M(), W);
            hist_lep_pt[channelNumber]->Fill(l1.Pt(), W);
            hist_lep_pt[channelNumber]->Fill(l2.Pt(), W);
            hist_met[channelNumber]->Fill(met_et/1000., W);            
        }
        */
        if(W >= 10){cout << "W =" << W << ": channelNumber = " << channelNumber << endl; }
    }
}
cout << "Done!" << endl;
// Out:
// Running over background...
// Number entries: 63330475
// ------------------------------------------
// 1 million events processed
// ------------------------------------------
// ------------------------------------------
// 2 million events processed
// ------------------------------------------
// W =11.218: channelNumber = 364100
// W =11.4138: channelNumber = 364100
// W =10.2639: channelNumber = 364100
// W =10.0392: channelNumber = 364100
// W =12.6071: channelNumber = 364100
// W =10.0753: channelNumber = 364100
// W =10.0737: channelNumber = 364100
// W =10.0521: channelNumber = 364100
// W =121.473: channelNumber = 364100
// W =13.2933: channelNumber = 364100
// W =11.9265: channelNumber = 364100
// W =17.414: channelNumber = 364100
// W =10.3475: channelNumber = 364100
// W =10.0702: channelNumber = 364100
// W =10.0992: channelNumber = 364100
// W =10.157: channelNumber = 364100
// W =37.8447: channelNumber = 364100
// W =20.1415: channelNumber = 364100
// W =16.6256: channelNumber = 364100
// W =14.6322: channelNumber = 364100
// W =10.1884: channelNumber = 364100
// W =13.8001: channelNumber = 364100
// W =10.0042: channelNumber = 364100
// ------------------------------------------
// 3 million events processed
// ------------------------------------------
// W =18.6999: channelNumber = 364100
// W =11.3629: channelNumber = 364100
// W =24.728: channelNumber = 364100
// W =10.1352: channelNumber = 364100
// W =10.1375: channelNumber = 364100
// W =16.2369: channelNumber = 364100
// W =13.4409: channelNumber = 364100
// W =12.7418: channelNumber = 364100
// W =16.8261: channelNumber = 364100
// W =11.0282: channelNumber = 364100
// W =10.6412: channelNumber = 364100
// W =38.3887: channelNumber = 364100
// W =10.1522: channelNumber = 364100
// W =10.1082: channelNumber = 364100
// W =10.2551: channelNumber = 364100
// W =29.0063: channelNumber = 364100
// W =16.8589: channelNumber = 364100
// W =10.0564: channelNumber = 364100
// W =11.0649: channelNumber = 364100
// W =14.9337: channelNumber = 364100
// W =17.1908: channelNumber = 364100
// W =17.1255: channelNumber = 364100
// W =10.0185: channelNumber = 364100
// W =10.0013: channelNumber = 364100
// W =28.6789: channelNumber = 364100
// W =17.2609: channelNumber = 364100
// W =11.2534: channelNumber = 364100
// W =12.1323: channelNumber = 364100
// W =10.4853: channelNumber = 364100
// W =10.1924: channelNumber = 364100
// W =21.724: channelNumber = 364100
// W =10.0986: channelNumber = 364100
// W =10.9051: channelNumber = 364100
// W =34.0306: channelNumber = 364100
// W =67.7904: channelNumber = 364100
// W =14.4298: channelNumber = 364100
// W =10.0305: channelNumber = 364100
// W =31.1685: channelNumber = 364100
// W =12.2029: channelNumber = 364100
// W =22.604: channelNumber = 364100
// W =11.7746: channelNumber = 364100
// W =10.1353: channelNumber = 364100
// W =11.2136: channelNumber = 364100
// W =20.6244: channelNumber = 364100
// W =28.3427: channelNumber = 364100
// W =12.5157: channelNumber = 364100
// W =48.4804: channelNumber = 364100
// W =14.6818: channelNumber = 364100
// W =10.1017: channelNumber = 364100
// W =14.9065: channelNumber = 364100
// W =11.2154: channelNumber = 364100
// W =26.8245: channelNumber = 364100
// W =10.7084: channelNumber = 364100
// W =18.6694: channelNumber = 364100
// W =10.0819: channelNumber = 364100
// W =32.2644: channelNumber = 364100
// W =10.0871: channelNumber = 364100
// W =10.9822: channelNumber = 364100
// W =20.7964: channelNumber = 364100
// W =36.22: channelNumber = 364100
// W =10.2451: channelNumber = 364100
// W =15.1754: channelNumber = 364100
// W =11.3845: channelNumber = 364100
// W =12.0594: channelNumber = 364100
// W =11.8095: channelNumber = 364100
// W =14.7908: channelNumber = 364100
// W =15.8828: channelNumber = 364100
// W =10.2466: channelNumber = 364100
// W =57.3278: channelNumber = 364100
// W =11.2983: channelNumber = 364100
// W =20.4413: channelNumber = 364100
// W =18.7255: channelNumber = 364100
// W =11.7235: channelNumber = 364100
// W =36.562: channelNumber = 364100
// W =10.3151: channelNumber = 364100
// W =10.2185: channelNumber = 364100
// W =10.8634: channelNumber = 364100
// W =15.2256: channelNumber = 364100
// W =10.2973: channelNumber = 364100
// W =17.1872: channelNumber = 364100
// W =10.3019: channelNumber = 364100
// W =11.2702: channelNumber = 364100
// W =16.5433: channelNumber = 364100
// W =13.8454: channelNumber = 364100
// W =10.2985: channelNumber = 364100
// W =11.8108: channelNumber = 364100
// W =10.3623: channelNumber = 364100
// W =12.3428: channelNumber = 364100
// W =15.2719: channelNumber = 364100
// W =52.1133: channelNumber = 364100
// W =10.0691: channelNumber = 364100
// W =10.1329: channelNumber = 364100
// W =15.4215: channelNumber = 364100
// W =13.1055: channelNumber = 364100
// W =22.7612: channelNumber = 364100
// W =146.384: channelNumber = 364100
// W =24.7624: channelNumber = 364100
// W =10.9736: channelNumber = 364100
// W =10.1391: channelNumber = 364100
// W =14.5641: channelNumber = 364100
// W =20.7037: channelNumber = 364100
// W =19.14: channelNumber = 364100
// W =14.2209: channelNumber = 364100
// W =12.7783: channelNumber = 364100
// W =11.5402: channelNumber = 364100
// W =19.7247: channelNumber = 364100
// W =18.9186: channelNumber = 364100
// W =10.135: channelNumber = 364100
// W =19.3739: channelNumber = 364100
// W =12.5032: channelNumber = 364100
// W =16.0304: channelNumber = 364100
// W =10.2169: channelNumber = 364100
// W =33.0527: channelNumber = 364100
// W =10.0987: channelNumber = 364100
// W =11.568: channelNumber = 364100
// W =12.9913: channelNumber = 364100
// W =12.6934: channelNumber = 364100
// W =10.1144: channelNumber = 364100
// W =13.3269: channelNumber = 364100
// W =10.2485: channelNumber = 364100
// W =10.0082: channelNumber = 364100
// W =10.1571: channelNumber = 364100
// W =10.2107: channelNumber = 364100
// W =11.0771: channelNumber = 364100
// W =20.8358: channelNumber = 364100
// W =10.245: channelNumber = 364100
// W =41.8159: channelNumber = 364100
// W =10.0051: channelNumber = 364100
// W =51.2483: channelNumber = 364100
// W =13.8017: channelNumber = 364100
// W =33.7737: channelNumber = 364100
// W =10.2058: channelNumber = 364100
// W =20.223: channelNumber = 364100
// W =10.1621: channelNumber = 364100
// W =10.4107: channelNumber = 364100
// W =10.0536: channelNumber = 364100
// W =11.523: channelNumber = 364100
// W =10.1233: channelNumber = 364100
// W =20.6193: channelNumber = 364100
// W =11.0212: channelNumber = 364100
// W =12.7915: channelNumber = 364100
// W =17.5891: channelNumber = 364100
// W =10.182: channelNumber = 364100
// W =10.2375: channelNumber = 364100
// W =17.1127: channelNumber = 364100
// W =10.1069: channelNumber = 364100
// W =25.6009: channelNumber = 364100
// W =18.4794: channelNumber = 364100
// W =11.6213: channelNumber = 364100
// W =10.1866: channelNumber = 364100
// W =32.1486: channelNumber = 364100
// W =14.0031: channelNumber = 364100
// W =23.1154: channelNumber = 364100
// W =11.6015: channelNumber = 364100
// W =10.9197: channelNumber = 364100
// W =11.5097: channelNumber = 364100
// W =13.2635: channelNumber = 364100
// W =12.2746: channelNumber = 364100
// W =14.0533: channelNumber = 364100
// W =10.45: channelNumber = 364100
// W =15.3155: channelNumber = 364100
// W =19.0543: channelNumber = 364100
// W =11.6336: channelNumber = 364100
// W =47.2609: channelNumber = 364100
// W =10.0481: channelNumber = 364100
// W =10.0617: channelNumber = 364100
// W =19.6343: channelNumber = 364100
// W =10.2818: channelNumber = 364100
// W =10.0055: channelNumber = 364100
// W =14.4657: channelNumber = 364100
// W =10.3261: channelNumber = 364100
// W =46.9638: channelNumber = 364100
// W =42.2274: channelNumber = 364100
// W =10.1331: channelNumber = 364100
// W =11.9092: channelNumber = 364100
// W =10.4102: channelNumber = 364100
// W =15.0186: channelNumber = 364100
// W =10.776: channelNumber = 364100
// W =16.5741: channelNumber = 364100
// W =14.965: channelNumber = 364100
// W =10.7044: channelNumber = 364100
// W =10.1287: channelNumber = 364100
// W =13.2915: channelNumber = 364100
// W =11.1177: channelNumber = 364100
// W =10.017: channelNumber = 364100
// W =10.9445: channelNumber = 364100
// W =11.0142: channelNumber = 364100
// W =11.7129: channelNumber = 364100
// W =11.0587: channelNumber = 364100
// W =10.6987: channelNumber = 364100
// W =31.3451: channelNumber = 364100
// W =11.7656: channelNumber = 364100
// W =15.0602: channelNumber = 364100
// W =14.7561: channelNumber = 364100
// W =12.4001: channelNumber = 364100
// W =10.148: channelNumber = 364100
// W =10.2244: channelNumber = 364100
// W =10.3592: channelNumber = 364100
// W =73.7755: channelNumber = 364100
// W =10.1877: channelNumber = 364100
// W =19.9316: channelNumber = 364100
// W =17.483: channelNumber = 364100
// W =20.2479: channelNumber = 364100
// W =14.6201: channelNumber = 364100
// W =10.3667: channelNumber = 364100
// W =116.564: channelNumber = 364100
// W =10.111: channelNumber = 364100
// W =10.0181: channelNumber = 364100
// W =10.0729: channelNumber = 364100
// W =20.8582: channelNumber = 364100
// W =10.014: channelNumber = 364100
// W =10.9742: channelNumber = 364100
// W =13.0383: channelNumber = 364100
// W =10.3602: channelNumber = 364100
// W =23.0134: channelNumber = 364100
// W =34.4466: channelNumber = 364100
// W =16.8542: channelNumber = 364100
// W =10.0929: channelNumber = 364100
// W =10.2102: channelNumber = 364100
// W =11.1571: channelNumber = 364100
// W =10.2053: channelNumber = 364100
// W =10.6606: channelNumber = 364100
// W =32.3439: channelNumber = 364100
// W =12.3284: channelNumber = 364100
// W =28.0941: channelNumber = 364100
// W =12.7444: channelNumber = 364100
// W =10.1557: channelNumber = 364100
// W =29.6416: channelNumber = 364100
// W =10.2246: channelNumber = 364100
// W =10.0609: channelNumber = 364100
// W =10.159: channelNumber = 364100
// W =10.0887: channelNumber = 364100
// W =11.1287: channelNumber = 364100
// W =14.3909: channelNumber = 364100
// W =11.6019: channelNumber = 364100
// W =15.6894: channelNumber = 364100
// W =10.1498: channelNumber = 364100
// W =10.038: channelNumber = 364100
// W =15.3031: channelNumber = 364100
// W =14.525: channelNumber = 364100
// W =10.0397: channelNumber = 364100
// W =10.2627: channelNumber = 364100
// W =24.4522: channelNumber = 364100
// W =10.048: channelNumber = 364100
// W =11.3925: channelNumber = 364100
// W =16.2833: channelNumber = 364100
// W =17.048: channelNumber = 364100
// W =10.2978: channelNumber = 364100
// W =10.2167: channelNumber = 364100
// W =22.5834: channelNumber = 364100
// W =20.0204: channelNumber = 364100
// W =10.386: channelNumber = 364100
// W =10.2281: channelNumber = 364100
// W =10.1671: channelNumber = 364100
// W =11.1176: channelNumber = 364100
// W =16.4511: channelNumber = 364100
// W =10.0118: channelNumber = 364100
// W =13.3503: channelNumber = 364100
// ------------------------------------------
// 4 million events processed
// ------------------------------------------
// W =16.436: channelNumber = 364100
// W =10.5946: channelNumber = 364100
// W =10.2602: channelNumber = 364100
// W =14.0524: channelNumber = 364100
// W =10.1123: channelNumber = 364100
// W =40.5184: channelNumber = 364100
// W =76.5103: channelNumber = 364100
// W =18.4562: channelNumber = 364100
// W =13.2626: channelNumber = 364100
// W =10.9127: channelNumber = 364100
// W =10.3645: channelNumber = 364100
// W =34.1284: channelNumber = 364100
// W =15.7301: channelNumber = 364100
// W =12.8734: channelNumber = 364100
// W =11.3298: channelNumber = 364100
// W =10.2597: channelNumber = 364100
// W =14.6466: channelNumber = 364100
// W =11.4993: channelNumber = 364100
// W =18.4869: channelNumber = 364100
// W =11.4727: channelNumber = 364100
// W =11.5034: channelNumber = 364100
// W =11.4937: channelNumber = 364100
// W =10.2257: channelNumber = 364100
// W =20.9946: channelNumber = 364100
// W =15.6281: channelNumber = 364100
// W =21.2602: channelNumber = 364100
// W =10.3034: channelNumber = 364100
// W =10.2206: channelNumber = 364100
// W =22.2354: channelNumber = 364100
// W =11.7797: channelNumber = 364100
// W =10.2952: channelNumber = 364100
// W =26.2773: channelNumber = 364100
// W =10.0145: channelNumber = 364100
// W =10.3507: channelNumber = 364100
// W =16.3084: channelNumber = 364100
// W =10.1052: channelNumber = 364100
// W =15.2667: channelNumber = 364100
// W =14.0741: channelNumber = 364100
// W =10.3614: channelNumber = 364100
// W =11.2418: channelNumber = 364100
// W =19.314: channelNumber = 364100
// W =21.4206: channelNumber = 364100
// W =10.1331: channelNumber = 364100
// W =10.0642: channelNumber = 364100
// W =10.5225: channelNumber = 364100
// W =11.6334: channelNumber = 364100
// W =10.0042: channelNumber = 364100
// W =22.1125: channelNumber = 364100
// W =11.5943: channelNumber = 364100
// W =10.533: channelNumber = 364100
// W =48.4777: channelNumber = 364100
// W =10.9917: channelNumber = 364100
// W =13.7695: channelNumber = 364100
// W =11.4091: channelNumber = 364100
// W =17.2422: channelNumber = 364100
// W =44.0781: channelNumber = 364100
// W =10.1182: channelNumber = 364100
// W =31.6399: channelNumber = 364100
// W =10.1962: channelNumber = 364100
// W =10.0415: channelNumber = 364100
// W =41.2814: channelNumber = 364100
// W =12.5907: channelNumber = 364100
// W =10.0433: channelNumber = 364100
// W =32.4795: channelNumber = 364100
// W =17.7775: channelNumber = 364100
// W =10.0775: channelNumber = 364100
// W =10.2517: channelNumber = 364100
// W =10.2166: channelNumber = 364100
// W =10.4243: channelNumber = 364100
// W =14.5883: channelNumber = 364100
// W =14.6208: channelNumber = 364100
// W =10.1902: channelNumber = 364100
// W =11.5466: channelNumber = 364100
// W =11.3603: channelNumber = 364100
// W =10.2891: channelNumber = 364100
// W =20.4526: channelNumber = 364100
// W =25.0018: channelNumber = 364100
// W =14.1247: channelNumber = 364100
// W =14.3487: channelNumber = 364100
// W =10.2024: channelNumber = 364100
// W =11.8896: channelNumber = 364100
// W =16.403: channelNumber = 364100
// W =23.1884: channelNumber = 364100
// W =10.1449: channelNumber = 364100
// W =14.3353: channelNumber = 364100
// W =18.5915: channelNumber = 364100
// W =10.4823: channelNumber = 364100
// W =49.9437: channelNumber = 364100
// W =10.085: channelNumber = 364100
// W =12.7872: channelNumber = 364100
// W =10.0568: channelNumber = 364100
// W =13.2187: channelNumber = 364100
// W =10.196: channelNumber = 364100
// W =15.2997: channelNumber = 364100
// W =11.0884: channelNumber = 364100
// W =23.0928: channelNumber = 364100
// W =10.0999: channelNumber = 364100
// W =10.3365: channelNumber = 364100
// W =10.9574: channelNumber = 364100
// W =10.0254: channelNumber = 364100
// W =19.0668: channelNumber = 364100
// W =10.0759: channelNumber = 364100
// W =15.1289: channelNumber = 364100
// W =23.5597: channelNumber = 364100
// W =10.0766: channelNumber = 364100
// W =11.0308: channelNumber = 364100
// W =10.9586: channelNumber = 364100
// W =10.0603: channelNumber = 364100
// W =15.5422: channelNumber = 364100
// W =10.6547: channelNumber = 364100
// W =17.7838: channelNumber = 364100
// W =10.3874: channelNumber = 364100
// W =21.5603: channelNumber = 364100
// W =13.5355: channelNumber = 364100
// W =10.0677: channelNumber = 364100
// W =15.2401: channelNumber = 364100
// W =19.0277: channelNumber = 364100
// W =25.1684: channelNumber = 364100
// W =11.1846: channelNumber = 364100
// W =11.3255: channelNumber = 364100
// W =10.0361: channelNumber = 364100
// W =10.0838: channelNumber = 364100
// W =26.8974: channelNumber = 364100
// W =12.3493: channelNumber = 364100
// W =13.8411: channelNumber = 364100
// W =17.7463: channelNumber = 364100
// W =25.4982: channelNumber = 364100
// W =26.6091: channelNumber = 364100
// W =11.0607: channelNumber = 364100
// W =16.6067: channelNumber = 364100
// W =10.5677: channelNumber = 364100
// W =13.474: channelNumber = 364100
// W =13.2794: channelNumber = 364100
// W =14.6147: channelNumber = 364100
// W =10.5686: channelNumber = 364100
// W =23.6544: channelNumber = 364100
// W =12.3227: channelNumber = 364100
// W =25.9999: channelNumber = 364100
// W =37.1982: channelNumber = 364100
// W =19.1425: channelNumber = 364100
// W =18.3844: channelNumber = 364100
// W =10.0436: channelNumber = 364100
// W =10.3726: channelNumber = 364100
// W =23.2265: channelNumber = 364100
// W =10.1648: channelNumber = 364100
// W =12.6877: channelNumber = 364100
// W =10.1016: channelNumber = 364100
// W =15.9721: channelNumber = 364100
// W =10.8818: channelNumber = 364100
// W =20.6928: channelNumber = 364100
// W =32.7736: channelNumber = 364100
// W =12.9941: channelNumber = 364100
// W =10.2787: channelNumber = 364100
// W =21.7745: channelNumber = 364100
// W =10.1976: channelNumber = 364100
// W =14.7582: channelNumber = 364100
// W =10.1017: channelNumber = 364100
// W =11.0385: channelNumber = 364100
// W =10.3361: channelNumber = 364100
// W =11.3465: channelNumber = 364100
// W =10.0014: channelNumber = 364100
// W =10.0993: channelNumber = 364100
// W =12.8793: channelNumber = 364100
// W =10.8975: channelNumber = 364100
// W =10.0774: channelNumber = 364100
// W =10.6965: channelNumber = 364100
// W =10.5373: channelNumber = 364100
// W =13.8303: channelNumber = 364100
// W =12.4742: channelNumber = 364100
// W =17.1703: channelNumber = 364100
// W =16.4032: channelNumber = 364100
// W =15.258: channelNumber = 364100
// W =10.0628: channelNumber = 364100
// W =12.4725: channelNumber = 364100
// W =11.339: channelNumber = 364100
// W =10.1927: channelNumber = 364100
// W =11.2921: channelNumber = 364100
// W =10.7726: channelNumber = 364100
// W =10.1831: channelNumber = 364100
// W =10.1787: channelNumber = 364100
// W =10.2878: channelNumber = 364100
// W =10.0642: channelNumber = 364100
// W =10.084: channelNumber = 364100
// W =10.3021: channelNumber = 364100
// W =10.2927: channelNumber = 364100
// W =12.0647: channelNumber = 364100
// W =18.1565: channelNumber = 364100
// W =10.2803: channelNumber = 364100
// W =10.5115: channelNumber = 364100
// W =10.9476: channelNumber = 364100
// W =11.5832: channelNumber = 364100
// W =12.2684: channelNumber = 364100
// W =28.2007: channelNumber = 364100
// W =15.887: channelNumber = 364100
// W =10.604: channelNumber = 364100
// W =13.2359: channelNumber = 364100
// W =11.0654: channelNumber = 364100
// W =50.0606: channelNumber = 364100
// W =16.3493: channelNumber = 364100
// W =10.0607: channelNumber = 364100
// W =10.1961: channelNumber = 364100
// W =10.0987: channelNumber = 364100
// W =10.0918: channelNumber = 364100
// W =10.7734: channelNumber = 364100
// W =17.9984: channelNumber = 364100
// W =10.0915: channelNumber = 364100
// W =12.6638: channelNumber = 364100
// W =10.1879: channelNumber = 364100
// W =17.2323: channelNumber = 364100
// W =43.9969: channelNumber = 364100
// W =19.8185: channelNumber = 364100
// W =28.4823: channelNumber = 364100
// W =21.8636: channelNumber = 364100
// W =15.1611: channelNumber = 364100
// W =10.1365: channelNumber = 364100
// W =12.1346: channelNumber = 364100
// W =13.4833: channelNumber = 364100
// W =24.1859: channelNumber = 364100
// W =13.1307: channelNumber = 364100
// W =10.0375: channelNumber = 364100
// W =16.2525: channelNumber = 364100
// W =10.2944: channelNumber = 364100
// W =21.8456: channelNumber = 364100
// W =11.8627: channelNumber = 364100
// W =12.1929: channelNumber = 364100
// W =13.4431: channelNumber = 364100
// W =13.455: channelNumber = 364100
// W =11.9022: channelNumber = 364100
// W =10.7095: channelNumber = 364100
// W =16.5809: channelNumber = 364100
// W =10.0008: channelNumber = 364100
// W =12.2434: channelNumber = 364100
// W =44.6207: channelNumber = 364100
// W =10.6242: channelNumber = 364100
// W =10.1072: channelNumber = 364100
// W =11.2797: channelNumber = 364100
// W =10.145: channelNumber = 364100
// W =10.0994: channelNumber = 364100
// W =10.8978: channelNumber = 364100
// W =27.3498: channelNumber = 364100
// W =16.3489: channelNumber = 364100
// W =13.0949: channelNumber = 364100
// W =10.0153: channelNumber = 364100
// W =12.4182: channelNumber = 364100
// W =10.6454: channelNumber = 364100
// W =10.032: channelNumber = 364100
// W =10.0417: channelNumber = 364100
// W =10.0056: channelNumber = 364100
// W =10.4767: channelNumber = 364100
// W =10.2551: channelNumber = 364100
// W =10.5297: channelNumber = 364100
// W =17.2584: channelNumber = 364100
// W =10.7307: channelNumber = 364100
// W =11.6521: channelNumber = 364100
// W =10.0216: channelNumber = 364100
// W =33.089: channelNumber = 364100
// ------------------------------------------
// 5 million events processed
// ------------------------------------------
// W =10.2323: channelNumber = 364100
// W =10.2348: channelNumber = 364100
// W =10.3595: channelNumber = 364100
// W =12.8489: channelNumber = 364100
// W =21.6069: channelNumber = 364100
// W =10.7739: channelNumber = 364100
// W =10.1647: channelNumber = 364100
// W =10.4427: channelNumber = 364101
// W =14.4431: channelNumber = 364101
// W =17.0079: channelNumber = 364101
// W =12.6851: channelNumber = 364101
// W =10.1688: channelNumber = 364101
// W =11.2515: channelNumber = 364101
// W =19.1288: channelNumber = 364101
// W =29.3341: channelNumber = 364101
// W =12.294: channelNumber = 364101
// W =28.7931: channelNumber = 364101
// W =99.4975: channelNumber = 364101
// W =90.807: channelNumber = 364101
// W =13.7136: channelNumber = 364101
// W =15.2797: channelNumber = 364101
// W =17.0773: channelNumber = 364101
// W =12.4599: channelNumber = 364101
// W =21.4407: channelNumber = 364101
// ------------------------------------------
// 6 million events processed
// ------------------------------------------
// W =15.2558: channelNumber = 364101
// W =11.1933: channelNumber = 364101
// W =11.2224: channelNumber = 364101
// W =20.7544: channelNumber = 364101
// W =14.7974: channelNumber = 364101
// W =18.8415: channelNumber = 364102
// W =19.2552: channelNumber = 364102
// ------------------------------------------
// 7 million events processed
// ------------------------------------------
// W =10.9667: channelNumber = 364102
// ------------------------------------------
// 8 million events processed
// ------------------------------------------
// W =10.3594: channelNumber = 364102
// W =12.0511: channelNumber = 364102
// W =19.2077: channelNumber = 364102
// ------------------------------------------
// 9 million events processed
// ------------------------------------------
// W =20.347: channelNumber = 364103
// W =12.0506: channelNumber = 364103
// W =10.1114: channelNumber = 364103
// W =17.566: channelNumber = 364103
// W =15.9497: channelNumber = 364103
// W =10.1635: channelNumber = 364103
// W =13.3938: channelNumber = 364103
// ------------------------------------------
// 10 million events processed
// ------------------------------------------
// W =12.8865: channelNumber = 364103
// W =11.09: channelNumber = 364103
// W =12.0704: channelNumber = 364103
// W =11.7952: channelNumber = 364103
// W =15.1289: channelNumber = 364103
// W =10.498: channelNumber = 364103
// W =14.141: channelNumber = 364103
// W =22.0612: channelNumber = 364103
// ------------------------------------------
// 11 million events processed
// ------------------------------------------
// W =11.711: channelNumber = 364104
// W =16.8432: channelNumber = 364104
// ------------------------------------------
// 12 million events processed
// ------------------------------------------
// ------------------------------------------
// 13 million events processed
// ------------------------------------------
// W =48.3302: channelNumber = 364106
// ------------------------------------------
// 14 million events processed
// ------------------------------------------
// ------------------------------------------
// 15 million events processed
// ------------------------------------------
// W =13.415: channelNumber = 364106
// ------------------------------------------
// 16 million events processed
// ------------------------------------------
// ------------------------------------------
// 17 million events processed
// ------------------------------------------
// ------------------------------------------
// 18 million events processed
// ------------------------------------------
// ------------------------------------------
// 19 million events processed
// ------------------------------------------
// ------------------------------------------
// 20 million events processed
// ------------------------------------------
// ------------------------------------------
// 21 million events processed
// ------------------------------------------
// ------------------------------------------
// 22 million events processed
// ------------------------------------------
// ------------------------------------------
// 23 million events processed
// ------------------------------------------
// W =12.8028: channelNumber = 364114
// W =53.739: channelNumber = 364114
// W =12.652: channelNumber = 364114
// W =10.3235: channelNumber = 364114
// W =12.6837: channelNumber = 364114
// W =64.8881: channelNumber = 364114
// W =38.4114: channelNumber = 364114
// W =60.6506: channelNumber = 364114
// W =15.5496: channelNumber = 364114
// W =11.8626: channelNumber = 364114
// W =11.138: channelNumber = 364114
// W =34.2679: channelNumber = 364114
// W =11.8809: channelNumber = 364114
// W =43.1285: channelNumber = 364114
// W =22.8517: channelNumber = 364114
// W =11.9648: channelNumber = 364114
// W =10.8932: channelNumber = 364114
// W =14.5146: channelNumber = 364114
// W =15.3164: channelNumber = 364114
// W =33.4186: channelNumber = 364114
// W =29.8841: channelNumber = 364114
// W =14.5206: channelNumber = 364114
// W =13.0972: channelNumber = 364114
// W =10.7432: channelNumber = 364114
// W =11.57: channelNumber = 364114
// W =13.7293: channelNumber = 364114
// W =372.5: channelNumber = 364114
// W =24.8628: channelNumber = 364114
// W =14.6055: channelNumber = 364114
// W =12.2999: channelNumber = 364114
// W =14.2729: channelNumber = 364114
// W =12.0124: channelNumber = 364114
// ------------------------------------------
// 24 million events processed
// ------------------------------------------
// W =10.3723: channelNumber = 364114
// W =14.1923: channelNumber = 364114
// W =13.3276: channelNumber = 364114
// W =38.5784: channelNumber = 364114
// W =14.0028: channelNumber = 364114
// W =10.9222: channelNumber = 364114
// W =11.137: channelNumber = 364114
// W =14.1244: channelNumber = 364114
// W =15.4684: channelNumber = 364114
// W =19.137: channelNumber = 364114
// W =11.248: channelNumber = 364114
// W =57.2104: channelNumber = 364114
// W =43.2316: channelNumber = 364114
// W =14.3617: channelNumber = 364114
// W =10.9422: channelNumber = 364114
// W =15.3745: channelNumber = 364114
// W =11.3434: channelNumber = 364114
// W =11.9203: channelNumber = 364114
// W =14.0944: channelNumber = 364114
// W =10.5609: channelNumber = 364114
// W =11.6307: channelNumber = 364114
// W =13.2478: channelNumber = 364114
// W =17.6527: channelNumber = 364114
// W =10.2072: channelNumber = 364114
// W =26.1598: channelNumber = 364114
// W =76.3479: channelNumber = 364114
// W =39.6939: channelNumber = 364114
// W =21.8419: channelNumber = 364114
// W =13.8191: channelNumber = 364114
// W =12.4923: channelNumber = 364114
// W =22.6282: channelNumber = 364114
// W =12.577: channelNumber = 364114
// W =11.0481: channelNumber = 364114
// W =11.9105: channelNumber = 364114
// W =41.3057: channelNumber = 364114
// W =18.3456: channelNumber = 364114
// W =10.1981: channelNumber = 364114
// W =12.9977: channelNumber = 364114
// W =18.3867: channelNumber = 364114
// W =13.2417: channelNumber = 364114
// W =15.3644: channelNumber = 364114
// W =12.695: channelNumber = 364114
// W =18.1364: channelNumber = 364114
// W =15.4401: channelNumber = 364114
// W =51.1125: channelNumber = 364114
// W =25.1145: channelNumber = 364114
// W =14.916: channelNumber = 364114
// W =13.3969: channelNumber = 364114
// W =13.1996: channelNumber = 364114
// W =10.0307: channelNumber = 364114
// W =11.2404: channelNumber = 364114
// W =22.3008: channelNumber = 364114
// W =12.5799: channelNumber = 364114
// W =13.4336: channelNumber = 364114
// W =11.3038: channelNumber = 364114
// W =11.3944: channelNumber = 364114
// W =14.8363: channelNumber = 364114
// W =16.6012: channelNumber = 364114
// W =22.056: channelNumber = 364114
// W =70.8678: channelNumber = 364114
// W =12.1729: channelNumber = 364114
// W =36.4575: channelNumber = 364114
// W =11.7871: channelNumber = 364114
// W =13.9025: channelNumber = 364114
// W =12.4503: channelNumber = 364114
// W =11.1653: channelNumber = 364114
// W =11.2691: channelNumber = 364114
// W =10.2782: channelNumber = 364114
// W =10.6861: channelNumber = 364114
// W =12.2723: channelNumber = 364114
// W =11.6825: channelNumber = 364114
// W =16.5888: channelNumber = 364114
// W =11.9637: channelNumber = 364114
// W =10.9317: channelNumber = 364114
// W =11.2581: channelNumber = 364114
// W =20.6865: channelNumber = 364114
// W =10.8081: channelNumber = 364114
// W =10.2663: channelNumber = 364114
// W =10.9827: channelNumber = 364114
// W =15.5634: channelNumber = 364114
// W =24.8113: channelNumber = 364114
// W =15.5151: channelNumber = 364114
// W =13.5013: channelNumber = 364114
// W =13.5709: channelNumber = 364114
// W =11.2163: channelNumber = 364114
// W =18.2772: channelNumber = 364114
// W =10.9825: channelNumber = 364114
// W =10.6608: channelNumber = 364114
// W =15.9099: channelNumber = 364114
// W =12.2011: channelNumber = 364114
// W =17.2882: channelNumber = 364114
// W =10.6315: channelNumber = 364114
// W =15.7832: channelNumber = 364114
// W =11.472: channelNumber = 364114
// W =22.8825: channelNumber = 364114
// W =12.7774: channelNumber = 364114
// W =11.71: channelNumber = 364114
// W =16.0493: channelNumber = 364114
// W =10.5693: channelNumber = 364114
// W =12.6296: channelNumber = 364114
// W =12.2766: channelNumber = 364114
// W =19.169: channelNumber = 364114
// W =15.4207: channelNumber = 364114
// W =14.2546: channelNumber = 364114
// W =13.8516: channelNumber = 364114
// W =15.7943: channelNumber = 364114
// W =18.5181: channelNumber = 364114
// W =13.2383: channelNumber = 364114
// W =11.2662: channelNumber = 364114
// W =10.1057: channelNumber = 364114
// W =24.6724: channelNumber = 364114
// W =34.6065: channelNumber = 364114
// W =12.4167: channelNumber = 364114
// W =11.9146: channelNumber = 364114
// W =10.0792: channelNumber = 364114
// W =10.6256: channelNumber = 364114
// W =13.2504: channelNumber = 364114
// W =21.0051: channelNumber = 364114
// W =12.0888: channelNumber = 364114
// W =10.0905: channelNumber = 364114
// W =17.5592: channelNumber = 364114
// W =10.5884: channelNumber = 364114
// W =28.3734: channelNumber = 364114
// W =11.166: channelNumber = 364114
// W =13.4579: channelNumber = 364114
// W =12.6248: channelNumber = 364114
// W =10.0273: channelNumber = 364114
// W =42.1246: channelNumber = 364114
// W =13.4106: channelNumber = 364114
// W =14.6073: channelNumber = 364114
// W =10.4599: channelNumber = 364114
// W =12.4121: channelNumber = 364114
// W =180.156: channelNumber = 364114
// W =17.184: channelNumber = 364114
// W =17.1176: channelNumber = 364114
// W =19.3147: channelNumber = 364114
// W =20.6076: channelNumber = 364114
// W =37.9202: channelNumber = 364114
// W =44.0647: channelNumber = 364114
// W =16.5206: channelNumber = 364114
// W =11.7011: channelNumber = 364114
// W =17.7633: channelNumber = 364114
// W =13.119: channelNumber = 364114
// W =12.3908: channelNumber = 364114
// W =10.7595: channelNumber = 364114
// W =10.4086: channelNumber = 364114
// W =11.6266: channelNumber = 364114
// W =14.2755: channelNumber = 364114
// W =18.0877: channelNumber = 364114
// W =11.8116: channelNumber = 364114
// W =12.7097: channelNumber = 364114
// W =13.077: channelNumber = 364114
// W =11.6771: channelNumber = 364114
// W =12.5019: channelNumber = 364114
// W =70.6371: channelNumber = 364114
// ------------------------------------------
// 25 million events processed
// ------------------------------------------
// W =11.2233: channelNumber = 364114
// W =40.013: channelNumber = 364114
// W =21.4753: channelNumber = 364114
// W =11.2271: channelNumber = 364114
// W =17.5841: channelNumber = 364114
// W =14.2169: channelNumber = 364114
// W =11.6465: channelNumber = 364114
// W =13.1704: channelNumber = 364114
// W =22.963: channelNumber = 364114
// W =10.2812: channelNumber = 364114
// W =84.0146: channelNumber = 364114
// W =16.1722: channelNumber = 364114
// W =11.5478: channelNumber = 364114
// W =14.0746: channelNumber = 364114
// W =11.596: channelNumber = 364114
// W =13.1029: channelNumber = 364114
// W =25.7446: channelNumber = 364114
// W =24.2743: channelNumber = 364114
// W =12.7983: channelNumber = 364114
// W =10.9443: channelNumber = 364114
// W =10.6065: channelNumber = 364114
// W =11.9554: channelNumber = 364114
// W =13.7701: channelNumber = 364114
// W =10.7758: channelNumber = 364114
// W =12.088: channelNumber = 364114
// W =10.3715: channelNumber = 364114
// W =14.4159: channelNumber = 364114
// W =15.2534: channelNumber = 364114
// W =16.8962: channelNumber = 364114
// W =10.547: channelNumber = 364114
// W =11.7527: channelNumber = 364114
// W =10.0689: channelNumber = 364114
// W =10.3673: channelNumber = 364114
// W =34.5219: channelNumber = 364114
// W =11.5139: channelNumber = 364114
// W =10.4034: channelNumber = 364114
// W =12.1251: channelNumber = 364114
// W =33.1325: channelNumber = 364114
// W =15.7815: channelNumber = 364114
// W =12.3102: channelNumber = 364114
// W =26.3979: channelNumber = 364114
// W =25.908: channelNumber = 364114
// W =63.9549: channelNumber = 364114
// W =16.2832: channelNumber = 364114
// W =11.3976: channelNumber = 364114
// W =10.908: channelNumber = 364114
// W =10.7059: channelNumber = 364114
// W =15.2026: channelNumber = 364114
// W =12.9016: channelNumber = 364114
// W =10.419: channelNumber = 364114
// W =31.6477: channelNumber = 364114
// W =12.0901: channelNumber = 364114
// W =37.1442: channelNumber = 364114
// W =12.3047: channelNumber = 364114
// W =52.6835: channelNumber = 364114
// W =10.287: channelNumber = 364114
// W =10.4112: channelNumber = 364114
// W =15.0307: channelNumber = 364114
// W =15.0209: channelNumber = 364114
// W =13.8897: channelNumber = 364114
// W =10.8234: channelNumber = 364114
// W =11.3884: channelNumber = 364114
// W =32.4763: channelNumber = 364114
// W =12.8651: channelNumber = 364114
// W =27.4818: channelNumber = 364114
// W =29.308: channelNumber = 364114
// W =11.2005: channelNumber = 364114
// W =14.004: channelNumber = 364114
// W =12.1193: channelNumber = 364114
// W =17.9914: channelNumber = 364114
// W =12.2314: channelNumber = 364114
// W =47.7659: channelNumber = 364114
// W =23.7601: channelNumber = 364114
// W =11.6583: channelNumber = 364114
// W =14.9595: channelNumber = 364114
// W =11.3203: channelNumber = 364114
// W =22.7859: channelNumber = 364114
// W =19.7104: channelNumber = 364114
// W =18.7637: channelNumber = 364114
// W =40.9433: channelNumber = 364114
// W =15.9537: channelNumber = 364114
// W =12.2679: channelNumber = 364114
// W =11.6752: channelNumber = 364114
// W =16.3567: channelNumber = 364114
// W =10.2659: channelNumber = 364114
// W =11.4548: channelNumber = 364114
// W =10.8539: channelNumber = 364114
// W =12.8997: channelNumber = 364114
// W =16.4112: channelNumber = 364114
// W =20.3287: channelNumber = 364114
// W =11.7207: channelNumber = 364114
// W =31.6944: channelNumber = 364114
// W =21.9936: channelNumber = 364114
// W =12.3959: channelNumber = 364114
// W =11.1634: channelNumber = 364114
// W =11.499: channelNumber = 364114
// W =10.4997: channelNumber = 364114
// W =10.7667: channelNumber = 364114
// W =24.9866: channelNumber = 364114
// W =30.507: channelNumber = 364114
// W =30.3341: channelNumber = 364114
// W =57.2018: channelNumber = 364114
// W =13.0066: channelNumber = 364114
// W =13.1979: channelNumber = 364114
// W =13.913: channelNumber = 364114
// W =34.3364: channelNumber = 364114
// W =11.4707: channelNumber = 364114
// W =10.1478: channelNumber = 364114
// W =20.298: channelNumber = 364114
// W =15.5844: channelNumber = 364114
// W =10.5975: channelNumber = 364114
// W =10.9135: channelNumber = 364114
// W =20.917: channelNumber = 364114
// W =17.1824: channelNumber = 364114
// W =12.6649: channelNumber = 364114
// W =12.5334: channelNumber = 364114
// W =10.301: channelNumber = 364114
// W =16.8722: channelNumber = 364114
// W =13.6687: channelNumber = 364114
// W =10.6029: channelNumber = 364114
// W =10.761: channelNumber = 364114
// W =21.1311: channelNumber = 364114
// W =11.3859: channelNumber = 364114
// W =26.8938: channelNumber = 364114
// W =47.9125: channelNumber = 364114
// W =21.1844: channelNumber = 364114
// W =14.7533: channelNumber = 364114
// W =11.9933: channelNumber = 364114
// W =10.9674: channelNumber = 364114
// W =11.3063: channelNumber = 364114
// W =18.2719: channelNumber = 364114
// W =10.0084: channelNumber = 364114
// W =18.9816: channelNumber = 364114
// W =23.0881: channelNumber = 364114
// W =10.4867: channelNumber = 364114
// W =10.4833: channelNumber = 364114
// W =10.033: channelNumber = 364114
// W =10.5783: channelNumber = 364114
// W =18.9703: channelNumber = 364115
// W =12.5692: channelNumber = 364115
// W =11.6432: channelNumber = 364115
// W =12.1668: channelNumber = 364115
// ------------------------------------------
// 26 million events processed
// ------------------------------------------
// W =18.6924: channelNumber = 364115
// W =12.0773: channelNumber = 364115
// W =13.4043: channelNumber = 364115
// W =11.0746: channelNumber = 364115
// W =19.1165: channelNumber = 364115
// W =11.0671: channelNumber = 364115
// W =13.2622: channelNumber = 364115
// W =11.1901: channelNumber = 364115
// W =16.5343: channelNumber = 364115
// W =16.1328: channelNumber = 364115
// W =10.4432: channelNumber = 364115
// W =11.1647: channelNumber = 364115
// W =10.0948: channelNumber = 364115
// W =25.4539: channelNumber = 364115
// W =18.5439: channelNumber = 364115
// W =75.5696: channelNumber = 364115
// W =10.5262: channelNumber = 364115
// W =12.3082: channelNumber = 364115
// ------------------------------------------
// 27 million events processed
// ------------------------------------------
// W =50.9336: channelNumber = 364115
// W =11.4244: channelNumber = 364115
// W =27.4026: channelNumber = 364115
// W =11.3463: channelNumber = 364115
// W =12.2438: channelNumber = 364115
// W =10.3205: channelNumber = 364115
// W =16.1883: channelNumber = 364116
// W =18.2878: channelNumber = 364116
// W =10.0151: channelNumber = 364116
// ------------------------------------------
// 28 million events processed
// ------------------------------------------
// W =14.3307: channelNumber = 364116
// W =16.8883: channelNumber = 364116
// W =24.3369: channelNumber = 364116
// W =31.4508: channelNumber = 364116
// W =13.5934: channelNumber = 364116
// W =14.7179: channelNumber = 364116
// W =22.9747: channelNumber = 364116
// ------------------------------------------
// 29 million events processed
// ------------------------------------------
// W =67.3118: channelNumber = 364116
// W =16.8499: channelNumber = 364116
// W =13.5828: channelNumber = 364116
// W =11.6172: channelNumber = 364116
// W =13.1397: channelNumber = 364116
// W =10.3783: channelNumber = 364116
// W =12.5874: channelNumber = 364116
// ------------------------------------------
// 30 million events processed
// ------------------------------------------
// W =21.5984: channelNumber = 364117
// W =22.477: channelNumber = 364117
// W =11.6207: channelNumber = 364117
// W =22.8665: channelNumber = 364117
// ------------------------------------------
// 31 million events processed
// ------------------------------------------
// W =21.5569: channelNumber = 364117
// W =25.436: channelNumber = 364117
// W =15.8195: channelNumber = 364117
// W =10.1889: channelNumber = 364117
// W =100.765: channelNumber = 364117
// W =26.8389: channelNumber = 364117
// ------------------------------------------
// 32 million events processed
// ------------------------------------------
// W =23.9642: channelNumber = 364117
// W =10.3195: channelNumber = 364118
// ------------------------------------------
// 33 million events processed
// ------------------------------------------
// ------------------------------------------
// 34 million events processed
// ------------------------------------------
// W =10.1081: channelNumber = 364119
// ------------------------------------------
// 35 million events processed
// ------------------------------------------
// ------------------------------------------
// 36 million events processed
// ------------------------------------------
// ------------------------------------------
// 37 million events processed
// ------------------------------------------
// ------------------------------------------
// 38 million events processed
// ------------------------------------------
// ------------------------------------------
// 39 million events processed
// ------------------------------------------
// ------------------------------------------
// 40 million events processed
// ------------------------------------------
// ------------------------------------------
// 41 million events processed
// ------------------------------------------
// ------------------------------------------
// 42 million events processed
// ------------------------------------------
// ------------------------------------------
// 43 million events processed
// ------------------------------------------
// ------------------------------------------
// 44 million events processed
// ------------------------------------------
// ------------------------------------------
// 45 million events processed
// ------------------------------------------
// ------------------------------------------
// 46 million events processed
// ------------------------------------------
// ------------------------------------------
// 47 million events processed
// ------------------------------------------
// ------------------------------------------
// 48 million events processed
// ------------------------------------------
// ------------------------------------------
// 49 million events processed
// ------------------------------------------
// ------------------------------------------
// 50 million events processed
// ------------------------------------------
// ------------------------------------------
// 51 million events processed
// ------------------------------------------
// ------------------------------------------
// 52 million events processed
// ------------------------------------------
// ------------------------------------------
// 53 million events processed
// ------------------------------------------
// ------------------------------------------
// 54 million events processed
// ------------------------------------------
// ------------------------------------------
// 55 million events processed
// ------------------------------------------
// ------------------------------------------
// 56 million events processed
// ------------------------------------------
// ------------------------------------------
// 57 million events processed
// ------------------------------------------
// ------------------------------------------
// 58 million events processed
// ------------------------------------------
// ------------------------------------------
// 59 million events processed
// ------------------------------------------
// ------------------------------------------
// 60 million events processed
// ------------------------------------------
// ------------------------------------------
// 61 million events processed
// ------------------------------------------
// ------------------------------------------
// 62 million events processed
// ------------------------------------------
// ------------------------------------------
// 63 million events processed
// ------------------------------------------
// Running over data...
// Number entries: 12205790
// ------------------------------------------
// 1 million events processed
// ------------------------------------------
// ------------------------------------------
// 2 million events processed
// ------------------------------------------
// ------------------------------------------
// 3 million events processed
// ------------------------------------------
// ------------------------------------------
// 4 million events processed
// ------------------------------------------
// ------------------------------------------
// 5 million events processed
// ------------------------------------------
// ------------------------------------------
// 6 million events processed
// ------------------------------------------
// ------------------------------------------
// 7 million events processed
// ------------------------------------------
// ------------------------------------------
// 8 million events processed
// ------------------------------------------
// ------------------------------------------
// 9 million events processed
// ------------------------------------------
// ------------------------------------------
// 10 million events processed
// ------------------------------------------
// ------------------------------------------
// 11 million events processed
// ------------------------------------------
// ------------------------------------------
// 12 million events processed
// ------------------------------------------
// Done!

// %%
cout << "zjets: " << zjets << ", ttbar: " << Ttbar << ", gravitons: " << gravitons << ", Zprime: " << zprime << ", dibosons: " << dibosons << ", tt: " << Tt << endl;
cout << "DSIDs size: " << DSIDs.size() <<  endl;
// Out:
// zjets: 25272844, ttbar: 435828, gravitons: 209486, Zprime: 0, dibosons: 3502787, tt: 0
// DSIDs size: 29420946

// %% [markdown]
// ### Ratio of data over predicted events
// Creating histogram containing ratio of events between data and that predicted by MC

// %%
/*
Create histogram containing ratio of events between data and that predicted by MC
*/
hist_mll_r = new TH1F();
hist_pt_r = new TH1F();
hist_met_r = new TH1F();

hist_mll_r->Reset();
hist_pt_r->Reset();
hist_met_r->Reset();

// %%
hist_mll_r = (TH1F*)hist_mll_d->Clone();
hist_pt_r = (TH1F*)hist_lep_pt_d->Clone();
hist_met_r = (TH1F*)hist_met_d->Clone();

hist_mll_r->Divide(hist_mll_d, hist_mll_sb);
hist_pt_r->Divide(hist_lep_pt_d, hist_lep_pt_sb);
hist_met_r->Divide(hist_met_d, hist_met_sb);

// %% [markdown]
// ### Background event histograms
// Assigning backgrounds according to their dataset ID's.

// %%
/*

3. Assign DSID histograms to corresponding background event histograms.

Make a new set of histograms, each corresponding to the different background categories, instead of the unique
dataset IDs. These histograms are made with the same range and binnings as above.
*/
map<TString, TH1*> H_mll; 
map<TString, TH1*> H_lep_pt;
map<TString, TH1*> H_met;

// %%
vector<TString> Backgrounds;

// %% [markdown]
// Adjusting the order of backgrounds according to how many events have been generated for each, in an ascending order.

// %%
// Must define the proper backgrounds for this dataset
Backgrounds = {"ttbar", "Dibosons", "Z+jets"};

// %%
for(const auto & i:Backgrounds){
    cout << "Background: " << i << endl;
    H_mll[i] = new TH1F();
    H_lep_pt[i] = new TH1F(); 
    H_met[i] = new TH1F();
}

// Reset histograms (in case you have filled them before) 
for(const auto i:Backgrounds){
    H_mll[i]->Reset();
    H_lep_pt[i]->Reset();
    H_met[i]->Reset();
}
// Out:
// Background: ttbar
// Background: Dibosons
// Background: Z+jets

// %%
// Define properties of background histograms
for(const auto & i:Backgrounds){
    H_mll[i]->SetNameTitle("hist_mll", "Invariant mass");
    H_lep_pt[i]->SetNameTitle("hist_lep_pt", "Lepton pT");
    H_met[i]->SetNameTitle("hist_met", "Missing ET");
    H_mll[i]->SetBins(30,0,2500); 
    H_lep_pt[i]->SetBins(30,0,2000);
    H_met[i]->SetBins(30,0,3000);
}

// %%
for(const auto i:dataset_IDs){
    if (std::find(ttbar.begin(), ttbar.end(), i) != ttbar.end()){
        H_mll["ttbar"]->Add(hist_mll[i]); 
        H_lep_pt["ttbar"]->Add(hist_lep_pt[i]);
        H_met["ttbar"]->Add(hist_met[i]);
//        cout << "Found " << i << " in ttbar" << "\n";
    }
    else if(std::find(Dibosons.begin(), Dibosons.end(), i) != Dibosons.end()){
        H_mll["Dibosons"]->Add(hist_mll[i]); 
        H_lep_pt["Dibosons"]->Add(hist_lep_pt[i]);
        H_met["Dibosons"]->Add(hist_met[i]);
//        cout << "Found " << i << " in Dibosons" << "\n"; 
    }

    else if(std::find(Zjets.begin(), Zjets.end(), i) != Zjets.end()){
        H_mll["Z+jets"]->Add(hist_mll[i]);
        H_lep_pt["Z+jets"]->Add(hist_lep_pt[i]);
        H_met["Z+jets"]->Add(hist_met[i]);
//        cout << "Found " << i << " in Zjets" << "\n"; 
    }

}

// %%
// Making new map containing the colours wanted for each background process, 
// and set the colours of the histogram

map<TString, Int_t> colors;

colors["graviton"] = 860; //kAzure;
colors["ttbar"] = 632; //kRed;
colors["Zprime"] = 840; //kTeal;
colors["Dibosons"] = 416; //kGreen;
colors["Z+jets"] = 400; //kYellow; 

for(const auto h:Backgrounds){
    H_mll[h]->SetFillColor(colors[h]); 
    H_met[h]->SetFillColor(colors[h]);
    H_lep_pt[h]->SetFillColor(colors[h]);
    
    H_mll[h]->SetLineColor(colors[h]); 
    H_met[h]->SetLineColor(colors[h]);
    H_lep_pt[h]->SetLineColor(colors[h]);
}

// %%
/*

4. Stack the background histograms

For each variable we need to stack the backgrounds on top of each other, which is done by using the THStack class. 
In the example below we do this for two variables; invariant mass and missing ET.

*/

THStack *stack_mll = new THStack("Invariant mass", "");
THStack *stack_met = new THStack("Missing ET", ""); 
THStack *stack_lep_pt = new THStack("Lepton pT", "");

for(const auto h:Backgrounds){
    // Remove previously stacked histograms  
    stack_mll->RecursiveRemove(H_mll[h]);
    stack_met->RecursiveRemove(H_met[h]);
    stack_lep_pt->RecursiveRemove(H_lep_pt[h]);

    //Add new stacked histograms
    stack_mll->Add(H_mll[h]);
    stack_met->Add(H_met[h]);
    stack_lep_pt->Add(H_lep_pt[h]);
}

// %%
gStyle->SetLegendBorderSize(0); // Remove (default) border around legend
TLegend *leg = new TLegend(0.65, 0.60, 0.9, 0.85);

// %%
leg->Clear();
leg->AddEntry(hist_mll_sb, "Graviton+background", "f");

// Add your histograms to the legend
for(const auto i:Backgrounds){
    leg->AddEntry(H_mll[i], i, "f");  
}
leg->AddEntry(hist_mll_d, "Data", "lep");

// %%
Float_t r = 0.3;
Float_t epsilon = 0.02;

TCanvas *C = new TCanvas("c", "c", 600, 600);

TPad *p1 = new TPad("p1", "", 0, 0.25, 1, 1);
TPad *p2 = new TPad("p2", "", 0, 0.0, 1, 0.25);

TPad *p3 = new TPad("p3", "", 0, 0.25, 1, 1);
TPad *p4 = new TPad("p4", "", 0, 0.0, 1, 0.25);

TPad *p5 = new TPad("p5", "", 0, 0.25, 1, 1);
TPad *p6 = new TPad("p6", "", 0, 0.0, 1, 0.25);

// %%
C->SetTicks(1, 1);
C->SetLeftMargin(0.13);

p1->SetLogy();
p1->SetBottomMargin(1e-5);
p1->Draw();
p1->cd();
//gPad->SetLogy(); // Set logarithmic y-axis
//gStyle->SetPadBorderMode(0);
//gStyle->SetFrameBorderMode(0);
gStyle->SetOptStat(0);
gStyle->SetOptTitle(0);
//p1->SetBottomMargin(small);

// %%
hist_mll_d->SetLineColor(kBlack);
hist_mll_d->SetMarkerStyle(kFullCircle);
hist_mll_d->SetMarkerColor(kBlack);

// %%
hist_mll_sb->SetFillColor(860); //kAzure

// %% [markdown]
// If there are less statistics, then it is more likely that the MC samples and real data will differ as
// MC predicts the amount of events one can expect at a certain range of e.g. m_ll. As long as the number of
// events of MC and real data do not differ too much at high statistics, e.g. 10^6 events,
// then MC is correct. If they do, then there is something wrong with the theory modelling the MC.

// %%
hist_mll_sb->Draw("hist");
hist_mll_sb->SetMaximum(1E8);     //set maximum range on axis
hist_mll_sb->SetMinimum(1e-3);
hist_mll_sb->GetXaxis()->SetLimits(0, 5000);
hist_mll_sb->GetYaxis()->SetTitle("# events");
hist_mll_sb->GetYaxis()->SetTitleOffset(1.3);
hist_mll_sb->GetXaxis()->SetTitle("m_{ll} (GeV)");
hist_mll_sb->GetXaxis()->SetTitleOffset(1.3);
hist_mll_sb->GetXaxis()->SetLabelSize(0);
stack_mll->Draw("same AH");
hist_mll_d->Draw("same E");
leg->Draw();

/*
s = TLatex();
s.SetNDC(1);
s.SetTextAlign(13);
s.SetTextColor(kBlack);
s.SetTextSize(0.044);
s.DrawLatex(0.4,0.86,"#font[72]{ATLAS} Open Data");
s.DrawLatex(0.4,0.81,"#bf{#sqrt{s} = 13 TeV,^{}%.1f^{}fb^{-1}}" % (L));
s.DrawLatex(0.4,0.76,"#bf{"+selection+" selection}");
*/

p1->Update();
p1->RedrawAxis();

C->cd();
// C->Draw();

// %%
p2->Draw();
p2->cd();
p2->SetGridy();

hist_mll_r->SetMaximum(1.99);
hist_mll_r->SetMinimum(0.01);
hist_mll_r->GetYaxis()->SetTitle("Data/pred.");
hist_mll_r->GetYaxis()->SetTitleSize(0.07);
hist_mll_r->GetYaxis()->SetLabelSize(0.07);
hist_mll_r->GetXaxis()->SetTitle("m_{ll} (GeV)");
hist_mll_r->GetXaxis()->SetTitleSize(0.11);
hist_mll_r->GetXaxis()->SetLabelSize(0.08);
hist_mll_r->SetMarkerStyle(kFullCircle);
hist_mll_r->SetMarkerColor(kBlack);
hist_mll_r->Draw("0PZ");
//hist_mll_r->GetYaxis()->SetTitle("Data/pred.");

p2->SetTopMargin(1e-5);
p2->SetBottomMargin(0.25); 
p2->SetLeftMargin(0.10);
p2->SetTickx();
p2->Update();
p2->RedrawAxis(); 

C->cd();
C->Update(); 
C->Draw();
//C_->Print("test.png")

// %%
hist_met_d->SetLineColor(kBlack);
hist_met_d->SetMarkerStyle(kFullCircle);
hist_met_d->SetMarkerColor(kBlack);

// %%
hist_met_sb->SetFillColor(860);  //kAzure

// %%
C->SetTicks(1, 1);
C->SetLeftMargin(0.13);

p3->SetLogy();
p3->SetBottomMargin(1e-5);
p3->Draw();
p3->cd();

hist_met_sb->Draw("hist"); 
hist_met_sb->SetMaximum(1E8);
hist_met_sb->SetMinimum(1E-2); 
hist_met_sb->GetYaxis()->SetTitle("# events");
hist_met_sb->GetYaxis()->SetTitleOffset(1.3); 
hist_met_sb->GetXaxis()->SetTitle("E_{T}^{miss} (GeV)");
hist_met_sb->GetXaxis()->SetTitleOffset(1.3);
stack_met->Draw("same AH");
hist_met_d->Draw("same e");
leg->Draw();

p3->Update();
p3->RedrawAxis();

C->cd();
// C->Draw();
/*
Often more difficult to model E_miss
*/

// %%
p4->Draw();
p4->cd();
p4->SetGridy();

hist_met_r->SetMaximum(1.99);
hist_met_r->SetMinimum(0.01);
hist_met_r->GetYaxis()->SetTitle("Data/pred.");
hist_met_r->GetYaxis()->SetTitleSize(0.07);
hist_met_r->GetYaxis()->SetLabelSize(0.07);
hist_met_r->GetXaxis()->SetTitle("E_{T}^{miss} (GeV)");
hist_met_r->GetXaxis()->SetTitleSize(0.11);
hist_met_r->GetXaxis()->SetLabelSize(0.055);
hist_met_r->SetMarkerStyle(kFullCircle);
hist_met_r->SetMarkerColor(kBlack);
hist_met_r->Draw("0PZ");
//hist_mll_r->GetYaxis()->SetTitle("Data/pred.");

p4->SetTopMargin(1e-5);
p4->SetBottomMargin(0.25); 
p4->Update();
p4->RedrawAxis(); 

C->cd();
C->Update(); 
C->Draw();
//C_->Print("test.png")

// %%
hist_lep_pt_d->SetLineColor(kBlack); 
hist_lep_pt_d->SetMarkerStyle(kFullCircle); 
hist_lep_pt_d->SetMarkerColor(kBlack);

// %%
hist_lep_pt_sb->SetFillColor(860); //kAzure

// %%
C->SetTicks(1, 1);
C->SetLeftMargin(0.13);

p5->SetLogy();
p5->SetBottomMargin(1e-5);
p5->Draw();
p5->cd();

hist_lep_pt_sb->Draw("hist"); 
hist_lep_pt_sb->SetMaximum(1E8); 
hist_lep_pt_sb->SetMinimum(1e-3);
hist_lep_pt_sb->GetYaxis()->SetTitle("# events");
hist_lep_pt_sb->GetYaxis()->SetTitleOffset(1.3); 
hist_lep_pt_sb->GetXaxis()->SetTitle("p_{T} (GeV)");
hist_lep_pt_sb->GetXaxis()->SetTitleOffset(1.3);
stack_lep_pt->Draw("same AH");
hist_lep_pt_d->Draw("same e"); 
leg->Draw();
//C->Draw();

p5->Update();
p5->RedrawAxis();

C->cd();

// %%
p6->Draw();
p6->cd();
p6->SetGridy();

hist_pt_r->SetMaximum(1.99);
hist_pt_r->SetMinimum(0.01);
hist_pt_r->GetYaxis()->SetTitle("Data/pred.");
hist_pt_r->GetYaxis()->SetTitleSize(0.07);
hist_pt_r->GetYaxis()->SetLabelSize(0.07);
hist_pt_r->GetXaxis()->SetTitle("p_{T} (GeV)");
hist_pt_r->GetXaxis()->SetTitleSize(0.11);
hist_pt_r->GetXaxis()->SetLabelSize(0.055);
hist_pt_r->SetMarkerStyle(kFullCircle);
hist_pt_r->SetMarkerColor(kBlack);
hist_pt_r->SetTitle("");
hist_pt_r->Draw("0PZ");
//hist_mll_r->GetYaxis()->SetTitle("Data/pred.");

p6->SetTopMargin(1e-5);
p6->SetBottomMargin(0.25);
p6->Update();
p6->RedrawAxis(); 

C->cd();
C->Update(); 
C->Draw();
//C->Print("test.pdf")

// %%
//cout << "Dibosons H_met: " << H_met.GetEntries() << " entries"<< endl;
